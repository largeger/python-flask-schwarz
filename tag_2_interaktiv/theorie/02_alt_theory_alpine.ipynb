# %% [markdown]
# # 🧪 Alternative Tag 2: Alpine.js & Flask - Die perfekte Mischung
#
# In diesem Notebook schauen wir uns an, wie wir unsere statischen Jinja2-Templates mit echtem Leben füllen, ohne JavaScript-Wüsten zu schreiben.

# %% [markdown]
# ## 1. Was ist Progressive Enhancement?
# Unsere Seite funktioniert auch ohne JavaScript (SEO-freundlich, schnell). Alpine.js fügt dann eine Schicht Interaktivität hinzu, die das Nutzererlebnis verbessert.

# %% [markdown]
# ## 2. Kommunikation zwischen Python und Alpine
# Flask liefert das Grundgerüst, Alpine übernimmt die lokale Logik im Browser.

# %%
# Stell dir vor, wir übergeben eine Liste von Kategorien an Jinja
categories = ['Web', 'Design', 'Data Science', 'Marketing']

# Im Template nutzen wir Jinja, um ein Alpine-Array zu füllen:
# <div x-data="{ filter: '{{ categories[0] }}' }">
#    Aktueller Filter: <span x-text="filter"></span>
# </div>

# %% [markdown]
# ## 3. Dynamische Suche (Client-Side Filtering)
# Wir können alle Daten einmal von Flask laden und Alpine filtern lassen, während der User tippt.

# %%
# Template Logik:
# <div x-data="{ search: '', items: ['Apfel', 'Banane', 'Kirsche'] }">
#    <input type='text' x-model='search' placeholder='Suche...'>
#    <ul>
#       <template x-for='item in items.filter(i => i.toLowerCase().includes(search.toLowerCase()))'>
#          <li x-text='item'></li>
#       </template>
#    </ul>
# </div>
