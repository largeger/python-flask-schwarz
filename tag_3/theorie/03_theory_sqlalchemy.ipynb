# %% [markdown]
# # 🧪 Tag 3: Datenbanken & SQLAlchemy
#
# Heute verbinden wir unsere App mit einer Datenbank.

# %% [markdown]
# ## 1. Was ist SQLite?
# SQLite ist eine dateibasierte Datenbank. Sie braucht keinen eigenen Server und ist perfekt für die Entwicklung.

# %%
# Config Beispiel
import os
basedir = os.path.abspath(os.path.dirname(__name__))
db_uri = 'sqlite:///' + os.path.join(basedir, 'data.sqlite')

# %% [markdown]
# ## 2. Modelle als Klassen
# Jede Klasse repräsentiert eine Tabelle.

# %%
class Todo(db.Model):
    id = db.Column(db.Integer, primary_key=True)
    task = db.Column(db.String(200), nullable=False)
    done = db.Column(db.Boolean, default=False)

# %% [markdown]
# ## 3. Abfragen (Querying)
# SQLAlchemy bietet eine sehr intuitive Syntax.

# %%
# Alle Todos holen
# todos = Todo.query.all()

# Nur erledigte holen
# done_todos = Todo.query.filter_by(done=True).all()
