# %% [markdown]
# # 🧪 Tag 2: Jinja2 & Dynamische Inhalte
#
# Heute lernen wir, wie wir Daten aus Python schick im Browser anzeigen.

# %% [markdown]
# ## 1. render_template
# Um ein HTML-File anzuzeigen, brauchen wir die Funktion `render_template`.

# %%
from flask import Flask, render_template

# Beispiel-Route (würde in app.py stehen)
# @app.route("/")
# def home():
#    return render_template("index.html", title="Startseite")

# %% [markdown]
# ## 2. Listen in HTML anzeigen
# Oft haben wir Listen von Daten (z.B. User, Produkte, News).

# %%
# In Python:
news = ["Flask 3.0 erschienen", "Python ist toll", "Wetter wird sonnig"]

# Im Template (HTML):
# {% for n in news %}
#   <div class='news-card'>{{ n }}</div>
# {% endfor %}

# %% [markdown]
# ## 3. Statische Assets
# Bilder, CSS und JavaScript kommen in den Ordner `static`.
# Wichtig: Wir verlinken sie nie hart (z.B. `/static/css/style.css`), sondern immer über `url_for`.

# %%
# Im HTML:
# <img src="{{ url_for('static', filename='img/logo.png') }}">
